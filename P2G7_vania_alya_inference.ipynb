# %% [markdown]
# # Graded Challenge 7 Inference - Food Classification (CNN)

# %% [markdown]
# ## Perkenalan

# %% [markdown]
# Name : Vania Alya Qonita <br>
# Batch : RMT 029 <br>
# <br>
#
# Latar belakang : Tingkat obesitas pada Indonesia telah meningkat menjadi 21,8%. Salah satu kunci dalam berat badan yang sehat adalah mencukupi dan menyeimbangkan jumlah kalori yang diterima oleh tubuh. Oleh karena itu, kita akan mencoba membuat sebuah kalori tracking dengan pendeteksian jenis makanan yang dimakan oleh user.
#
# Tujuan : Membuat model CNN untuk dapat melakukan klasifikasi terhadap gambar makanan.

# %% [markdown]
# ## Import Library

# %%
# Import library yang akan digunakan
import pandas as pd
import numpy as np
import zipfile
import tensorflow as tf
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Data Loading
# Data inference akan menggunakan data test yang belum diberikan label dari dataset Food Classification.
#
# Melakukan data loading menggunakan API key dari kaggle. Mohon siapkan kaggle API file untuk dilakukan uploading pada proses ini.

# %%
# Melakukan installing kaggle
! pip install -q kaggle

# %%
# Upload kaggle API file disini
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-66d0befc-3907-4fbb-8e6f-37f135863f12" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66d0befc-3907-4fbb-8e6f-37f135863f12">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Membuat directory bernama kaggle dan melakukan copy file kaggle.json
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/

# %%
# Merubah permission dari file
! chmod 600 ~/.kaggle/kaggle.json

# %%
# Mendownload data Uber and Lyft dataset
# !kaggle datasets download -d bjoernjostein/food-classification
# Out:
# ...
#  99% 747M/753M [00:08<00:00, 141MB/s]
# 100% 753M/753M [00:08<00:00, 91.1MB/s]

# %%
# Dikarenakan data yang di download dalam bentuk ZIP, maka kita lakukan unzip pada data
zip_ref = zipfile.ZipFile('food-classification.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %% [markdown]
# ## Model Loading

# %%
# Load model
model_cnn = load_model('food_cnn_model1.keras')
# Out:
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 1 variables whereas the saved optimizer has 21 variables.

# %%
# Functions from python file
from food_classif_pred import prediction

# %%
# Load dataset
df_kalori = pd.read_csv('food_classif_kalori.csv')

# %% [markdown]
# ## Model Inference
# Model yang telah dilakukan training akan melakukan prediksi terhadap data yang belum dilihat sebelumnya.

# %%
# Melakukan prediksi terhadap test set
prediction('/content/test_images/test_images/0206101929.jpg', model_cnn, df_kalori)
# Out:
# 1/1 [==============================] - 0s 263ms/step
# Prediction is a broccoli
# Kalori : 34

# %% [markdown]
# Dari gambar yang telah dimasukkan, model memprediksi bahwa gambar termasuk kelas `broccoli` dengan kalori sebesar 34 kal.

# %%
# Melakukan prediksi terhadap test set
prediction('/content/test_images/test_images/0465f6d586.jpg', model_cnn, df_kalori)
# Out:
# 1/1 [==============================] - 0s 51ms/step
# Prediction is a egg
# Kalori : 155

# %% [markdown]
# Dari gambar yang telah dimasukkan, model memprediksi bahwa gambar termasuk kelas `egg` dengan kalori sebesar 155 kal.

# %%
# Melakukan prediksi terhadap test set
prediction('/content/test_images/test_images/0a3c32bc94.jpg', model_cnn, df_kalori)
# Out:
# 1/1 [==============================] - 0s 51ms/step
# Prediction is a salad-leaf-salad-green
# Kalori : 15

# %% [markdown]
# Dari gambar yang telah dimasukkan, model memprediksi bahwa gambar termasuk kelas `salad-leaf-salad-green` dengan kalori sebesar 15 kal.
